# %%
import pandas as pd
df = pd.read_json("/root/workspace/culfjk4p420c73amv510/herunming/Bigmath_all_synth_20000_pseudo.jsonl",lines=True)
df.head()
# Out:
#                                               prompt            solution  \
# 0  Given that ${a_n}$ is an arithmetic sequence, ...        \frac{1}{10}
# 1  A luxury liner, Queen Mary II, is transporting...                   7
# 2  Find the conjugate of the complex number $\fra...                 1-i
# 3  Given the solution set of the inequality $x^2+...  (-2, -\frac{1}{2})
# 4  A positive integer $a$ is input into a machine...                 218
#
#       source                                             domain  \
# 0     cn_k12   [Mathematics -> Algebra -> Sequences and Series]
# 1  orca_math  [Mathematics -> Applied Mathematics -> Math Wo...
# 2   big_math  [Mathematics -> Algebra -> Intermediate Algebr...
# 3     cn_k12  [Mathematics -> Algebra -> Equations and Inequ...
# 4   omnimath  [Mathematics -> Applied Mathematics -> Math Wo...
#
#    llama8b_solve_rate                                 generated_question  \
# 0            0.281250  A company produces widgets, and the production...
# 1            0.234375  A bird sanctuary features several species of b...
# 2            0.671875  Sarah invests $500 in a savings account that o...
# 3            0.265625  A company's monthly profit, P(x), in thousands...
# 4            0.093750  A city park is planning to build a skate ramp....
#
#                                    pseudo_answers  \
# 0  [0.01125, 0.01125, 0.01125, 0.01125, 1.141875]
# 1                                 [7, 7, 7, 7, 1]
# 2               [19.56, 19.56, 20.91, 1.5, 19.56]
# 3                           [3996, 2, 4000, 0, 0]
# 4                         [104, 3, 104, 104, 104]
#
#                                     pseudo_solutions  \
# 0  [To find the common difference \( d \), we beg...
# 1  [Let's define variables to solve the problem:\...
# 2  [To find the balance \( X \) at the end of 3 y...
# 3  [Let's analyze the problem and solve step by s...
# 4  [First, let's calculate the total additions to...
#
#                      pseudo_correct_solution_example pseudo_answer_value
# 0  To find the common difference \( d \), we begi...             0.01125
# 1  Let's define variables to solve the problem:\n...                   7
# 2  To find the balance \( X \) at the end of 3 ye...               19.56
# 3  Let's analyze the problem and solve step by st...                   0
# 4  First, let's calculate the total additions to ...                 104

# %%
# 保留["generated_question","pseudo_correct_solution_example","pseudo_answer_value"]
df = df[["generated_question","pseudo_correct_solution_example","pseudo_answer_value"]]
df.head()
# Out:
#                                   generated_question  \
# 0  A company produces widgets, and the production...
# 1  A bird sanctuary features several species of b...
# 2  Sarah invests $500 in a savings account that o...
# 3  A company's monthly profit, P(x), in thousands...
# 4  A city park is planning to build a skate ramp....
#
#                      pseudo_correct_solution_example pseudo_answer_value
# 0  To find the common difference \( d \), we begi...             0.01125
# 1  Let's define variables to solve the problem:\n...                   7
# 2  To find the balance \( X \) at the end of 3 ye...               19.56
# 3  Let's analyze the problem and solve step by st...                   0
# 4  First, let's calculate the total additions to ...                 104

# %%
df.to_json("/root/workspace/culfjk4p420c73amv510/herunming/Bigmath_synth_20000.jsonl",lines=True,orient="records")

# %%
import pandas as pd

df = pd.read_json("/root/workspace/culfjk4p420c73amv510/herunming/DataFlow/demos/demos_result/math/pipeline_Q/Corrected_step2.jsonl",lines=True)
